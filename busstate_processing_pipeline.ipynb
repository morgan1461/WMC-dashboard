# %% [markdown]
# # BusState Data Processing Pipeline (Python)
#
# ### Overview
#
# This notebook processes raw **BusState APC data** from compressed `.txt.zip` files into clean, structured datasets for downstream analysis and dashboarding.
#
# The workflow is a Python translation of an existing R-based pipeline previously used in the OSU Department of Transportation and Traffic Management (TTM), with improvements for modularity, readability, and scalability.
#
# ---
#
# ### Data Source
#
# * Directory: `K:/AP/TTM/Data/APC Data/`
# * File format: `compressed .txt`
# * Naming convention:
#
#   ```
#   busstate0####DDMMYY.txt.zip
#   ```
#
#   * `####` = bus identifier
#   * `DD` = day
#   * `MM` = month
#   * `YY` = year (2-digit)
#
# ---
#
# ### Output
#
# * Data is split into monthly subsets
#
# * Saved as `.csv` files:
#
#   ```
#   YYYY-MMM-busstate.csv
#   ```
#
# * Example:
#
#   ```
#   2025-OCT-busstate.csv
#   ```
#
# * Output directory:
#
#   ```
#   K:/AP/TTM/Data/CM_WMC-Dashboard/busstate_cleaned/
#   ```
#
# ---
#
# ### Notes
#
# * This will take around 3-4 minutes to run for one month worth of data.
# * If this is run on a Unix based machine, changes will need to be made to the root directory.
# * Potential issues with overwriting in the sort_and_save function when running a new month with existing data. - will revisit
#
# ---
#
# ### Author
#
# * Writen by Clayton Morgan (morgan.1461) Reporting and Analytics Analyst at The Ohio State University
# * Python implementation of legacy R workflow in the TTM

# %%
# STEP 1: Import busstate processing module
from modules import busstate_processing as bp

# %% [markdown]
# **Note**: The year and month fields must be in 2 digit format, within the quotations.
#
# e.g) For October, 2025
#
# year = "25"
#
# month = "09"

# %%
# STEP 2: Set month and year of interest for dashboard
year = "26"
month = "01"

# %%
# STEP 3: Run processing pipeline to clean busstate data for month and year of interest
# bp.busstate_processing(year, month)

for i in range(1, 5):
    print(f"Running busstate processing pipeline for month {month} and year {year}, iteration {i}...")
    month = f"0{i}"
    bp.busstate_processing(year, month)
# Out:
# Running busstate processing pipeline for month 04 and year 26, iteration 1...
# Starting busstate processing for 01/26...
# Found 1003 busstate files for 01/26 (including +/- 2 day overlap) in 'K:\AP\TTM\Data\APC Data'
# Unzipping and processing busstate files for 01/26...
# Combined dataframe has 959307 records for 01/26
# Saved 892357 records for JAN 2026 to '\\osuad.osu.edu\files\AP\TTM\Data\WMC_Dashboard\busstate_cleaned\2026-JAN-busstate.csv'
# Saved 7782 records for FEB 2026 to '\\osuad.osu.edu\files\AP\TTM\Data\WMC_Dashboard\busstate_cleaned\2026-FEB-busstate.csv'
# No data for month MAR 2026
# No data for month APR 2026
# No data for month MAY 2026
# No data for month JUN 2026
# No data for month JUL 2026
# No data for month AUG 2026
# No data for month SEP 2026
# No data for month OCT 2026
# No data for month NOV 2026
# No data for month DEC 2026
# Finished processing busstate data for 01/26 in 199.41 seconds. Cleaned files saved to '\\osuad.osu.edu\files\AP\TTM\Data\WMC_Dashboard\busstate_cleaned'
# Running busstate processing pipeline for month 01 and year 26, iteration 2...
# Starting busstate processing for 02/26...
# Found 980 busstate files for 02/26 (including +/- 2 day overlap) in 'K:\AP\TTM\Data\APC Data'
# Unzipping and processing busstate files for 02/26...
# Combined dataframe has 1105762 records for 02/26
# Merged with existing file and removed 1796 duplicate records for JAN 2026
# Saved 991762 records for JAN 2026 to '\\osuad.osu.edu\files\AP\TTM\Data\WMC_Dashboard\busstate_cleaned\2026-JAN-busstate.csv'
# Merged with existing file and removed 1462 duplicate records for FEB 2026
# Saved 1003592 records for FEB 2026 to '\\osuad.osu.edu\files\AP\TTM\Data\WMC_Dashboard\busstate_cleaned\2026-FEB-busstate.csv'
# Saved 7277 records for MAR 2026 to '\\osuad.osu.edu\files\AP\TTM\Data\WMC_Dashboard\busstate_cleaned\2026-MAR-busstate.csv'
# No data for month APR 2026
# No data for month MAY 2026
# No data for month JUN 2026
# No data for month JUL 2026
# No data for month AUG 2026
# No data for month SEP 2026
# No data for month OCT 2026
# No data for month NOV 2026
# No data for month DEC 2026
# Finished processing busstate data for 02/26 in 244.16 seconds. Cleaned files saved to '\\osuad.osu.edu\files\AP\TTM\Data\WMC_Dashboard\busstate_cleaned'
# Running busstate processing pipeline for month 02 and year 26, iteration 3...
# Starting busstate processing for 03/26...
# Found 1087 busstate files for 03/26 (including +/- 2 day overlap) in 'K:\AP\TTM\Data\APC Data'
# Unzipping and processing busstate files for 03/26...
# Combined dataframe has 1190085 records for 03/26
# No data for month JAN 2026
# Merged with existing file and removed 7862 duplicate records for FEB 2026
# Saved 1093369 records for FEB 2026 to '\\osuad.osu.edu\files\AP\TTM\Data\WMC_Dashboard\busstate_cleaned\2026-FEB-busstate.csv'
# Merged with existing file and removed 980 duplicate records for MAR 2026
# Saved 1047721 records for MAR 2026 to '\\osuad.osu.edu\files\AP\TTM\Data\WMC_Dashboard\busstate_cleaned\2026-MAR-busstate.csv'
# Saved 51022 records for APR 2026 to '\\osuad.osu.edu\files\AP\TTM\Data\WMC_Dashboard\busstate_cleaned\2026-APR-busstate.csv'
# No data for month MAY 2026
# No data for month JUN 2026
# No data for month JUL 2026
# No data for month AUG 2026
# No data for month SEP 2026
# No data for month OCT 2026
# No data for month NOV 2026
# No data for month DEC 2026
# Finished processing busstate data for 03/26 in 267.54 seconds. Cleaned files saved to '\\osuad.osu.edu\files\AP\TTM\Data\WMC_Dashboard\busstate_cleaned'
# Running busstate processing pipeline for month 03 and year 26, iteration 4...
# Starting busstate processing for 04/26...
# Found 1074 busstate files for 04/26 (including +/- 2 day overlap) in 'K:\AP\TTM\Data\APC Data'
# Unzipping and processing busstate files for 04/26...
# Combined dataframe has 1256590 records for 04/26
# No data for month JAN 2026
# No data for month FEB 2026
# Merged with existing file and removed 7388 duplicate records for MAR 2026
# Saved 1175974 records for MAR 2026 to '\\osuad.osu.edu\files\AP\TTM\Data\WMC_Dashboard\busstate_cleaned\2026-MAR-busstate.csv'
# Merged with existing file and removed 1156 duplicate records for APR 2026
# Saved 1150374 records for APR 2026 to '\\osuad.osu.edu\files\AP\TTM\Data\WMC_Dashboard\busstate_cleaned\2026-APR-busstate.csv'
# Saved 20428 records for MAY 2026 to '\\osuad.osu.edu\files\AP\TTM\Data\WMC_Dashboard\busstate_cleaned\2026-MAY-busstate.csv'
# No data for month JUN 2026
# No data for month JUL 2026
# No data for month AUG 2026
# No data for month SEP 2026
# No data for month OCT 2026
# No data for month NOV 2026
# No data for month DEC 2026
# Finished processing busstate data for 04/26 in 283.15 seconds. Cleaned files saved to '\\osuad.osu.edu\files\AP\TTM\Data\WMC_Dashboard\busstate_cleaned'
